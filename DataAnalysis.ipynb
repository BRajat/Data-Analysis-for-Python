# %% [markdown]
# ### Loading the data

# %% [markdown]
# * Downloading single IRIS dataset file, with wget

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data
# Out:
# --2022-02-23 15:37:34--  https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4551 (4.4K) [application/x-httpd-php]
# Saving to: ‘iris.data’
#
# iris.data           100%[===================>]   4.44K  --.-KB/s    in 0s
#
# 2022-02-23 15:37:35 (350 MB/s) - ‘iris.data’ saved [4551/4551]

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.4.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      |████████████████████████████████| 11.7 MB 488 kB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/rajat/miniconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1
#   Downloading pytz-2021.3-py2.py3-none-any.whl (503 kB)
#      |████████████████████████████████| 503 kB 1.3 MB/s eta 0:00:01
# Collecting numpy>=1.18.5
#   Downloading numpy-1.22.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#      |████████████████████████████████| 16.8 MB 1.6 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.5 in /home/rajat/miniconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: pytz, numpy, pandas
# Successfully installed numpy-1.22.2 pandas-1.4.1 pytz-2021.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.11.2-py3-none-any.whl (292 kB)
#      |████████████████████████████████| 292 kB 2.0 MB/s eta 0:00:01
# Collecting matplotlib>=2.2
#   Downloading matplotlib-3.5.1-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 6.3 MB/s eta 0:00:01
# Collecting scipy>=1.0
#   Downloading scipy-1.8.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.1 MB)
#      |████████████████████████████████| 42.1 MB 2.3 MB/s eta 0:00:01
# Requirement already satisfied: pandas>=0.23 in /home/rajat/miniconda3/lib/python3.9/site-packages (from seaborn) (1.4.1)
# Requirement already satisfied: numpy>=1.15 in /home/rajat/miniconda3/lib/python3.9/site-packages (from seaborn) (1.22.2)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.2-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 2.1 MB/s eta 0:00:01
# Requirement already satisfied: pyparsing>=2.2.1 in /home/rajat/miniconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (3.0.4)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.0.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 1.3 MB/s eta 0:00:01
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.29.1-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 134 kB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7 in /home/rajat/miniconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /home/rajat/miniconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: pytz>=2020.1 in /home/rajat/miniconda3/lib/python3.9/site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in /home/rajat/miniconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Installing collected packages: pillow, kiwisolver, fonttools, cycler, scipy, matplotlib, seaborn
# Successfully installed cycler-0.11.0 fonttools-4.29.1 kiwisolver-1.3.2 matplotlib-3.5.1 pillow-9.0.1 scipy-1.8.0 seaborn-0.11.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('iris.data', header = None)
df.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
df.columns = ['Sepal_length','Sepal_width','Petal_length','Petal_width','Species']

# %%
df.head()
# Out:
#    Sepal_length  Sepal_width  Petal_length  Petal_width      Species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# describing data
df.describe()
# Out:
#        Sepal_length  Sepal_width  Petal_length  Petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# visualization of data
sns.scatterplot(data = df, x = 'Sepal_length', y = 'Sepal_width', hue = 'Species')
# Out:
# <AxesSubplot:xlabel='Sepal_length', ylabel='Sepal_width'>

# %%
sns.pairplot(data = df, hue = 'Species')

# %%
sns.boxplot(data = df, x = 'Species', y = 'Sepal_width')
# Out:
# <AxesSubplot:xlabel='Species', ylabel='Sepal_width'>

# %%
# aggregation with group by - find the mean sepal width of different species
df.groupby('Species').agg({'mean'})['Sepal_width']
# Out:
#                   mean
# Species
# Iris-setosa      3.418
# Iris-versicolor  2.770
# Iris-virginica   2.974

# %%
# heatmap

sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
pip install sweetviz
# Out:
# Collecting sweetviz
#   Downloading sweetviz-2.1.3-py3-none-any.whl (15.1 MB)
#      |████████████████████████████████| 15.1 MB 5.2 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.16.0 in /home/rajat/miniconda3/lib/python3.9/site-packages (from sweetviz) (1.22.2)
# Requirement already satisfied: jinja2>=2.11.1 in /home/rajat/miniconda3/lib/python3.9/site-packages (from sweetviz) (3.0.2)
# Collecting importlib-resources>=1.2.0
#   Downloading importlib_resources-5.4.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: scipy>=1.3.2 in /home/rajat/miniconda3/lib/python3.9/site-packages (from sweetviz) (1.8.0)
# Requirement already satisfied: matplotlib>=3.1.3 in /home/rajat/miniconda3/lib/python3.9/site-packages (from sweetviz) (3.5.1)
# Requirement already satisfied: tqdm>=4.43.0 in /home/rajat/miniconda3/lib/python3.9/site-packages (from sweetviz) (4.62.3)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in /home/rajat/miniconda3/lib/python3.9/site-packages (from sweetviz) (1.4.1)
# Requirement already satisfied: zipp>=3.1.0 in /home/rajat/miniconda3/lib/python3.9/site-packages (from importlib-resources>=1.2.0->sweetviz) (3.7.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/rajat/miniconda3/lib/python3.9/site-packages (from jinja2>=2.11.1->sweetviz) (2.0.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/rajat/miniconda3/lib/python3.9/site-packages (from matplotlib>=3.1.3->sweetviz) (9.0.1)
# Requirement already satisfied: packaging>=20.0 in /home/rajat/miniconda3/lib/python3.9/site-packages (from matplotlib>=3.1.3->sweetviz) (21.3)
# Requirement already satisfied: cycler>=0.10 in /home/rajat/miniconda3/lib/python3.9/site-packages (from matplotlib>=3.1.3->sweetviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/rajat/miniconda3/lib/python3.9/site-packages (from matplotlib>=3.1.3->sweetviz) (4.29.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/rajat/miniconda3/lib/python3.9/site-packages (from matplotlib>=3.1.3->sweetviz) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/rajat/miniconda3/lib/python3.9/site-packages (from matplotlib>=3.1.3->sweetviz) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/rajat/miniconda3/lib/python3.9/site-packages (from matplotlib>=3.1.3->sweetviz) (3.0.4)
# Requirement already satisfied: pytz>=2020.1 in /home/rajat/miniconda3/lib/python3.9/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2021.3)
# Requirement already satisfied: six>=1.5 in /home/rajat/miniconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.16.0)
# Installing collected packages: importlib-resources, sweetviz
# Successfully installed importlib-resources-5.4.0 sweetviz-2.1.3
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### EDA in Sweetviz
# Reference -https://pypi.org/project/sweetviz/

# %%
# EDA via sweetviz
import sweetviz as sv

my_report = sv.analyze(df)
my_report.show_html()                        # Default arguments will generate to "SWEETVIZ_REPORT.html"
# Out:
#                                              |      | [  0%]   00:00 -> (? left)
# /home/rajat/miniconda3/lib/python3.9/site-packages/sweetviz/graph_associations.py:223: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(pd.Series(empty_row_dict, name=feature))
# /home/rajat/miniconda3/lib/python3.9/site-packages/sweetviz/graph_associations.py:223: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(pd.Series(empty_row_dict, name=feature))
# /home/rajat/miniconda3/lib/python3.9/site-packages/sweetviz/graph_associations.py:223: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(pd.Series(empty_row_dict, name=feature))
# /home/rajat/miniconda3/lib/python3.9/site-packages/sweetviz/graph_associations.py:223: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(pd.Series(empty_row_dict, name=feature))
# /home/rajat/miniconda3/lib/python3.9/site-packages/sweetviz/graph_associations.py:223: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(pd.Series(empty_row_dict, name=feature))
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
